# %%
import numpy as np
import time
from sklearn import decomposition, linear_model, datasets
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
breast_cancer  = datasets.load_breast_cancer()

# %%
X = breast_cancer.data
y = breast_cancer.target

# %%
X.shape  #30 - no of features
# Out:
# (569, 30)

# %%
#Applying feature scaling
sc = StandardScaler()
X_std = sc.fit_transform(X)

# %%
 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# # We fit pca only on training data, and apply the same pca object on test data

# %%
pca = decomposition.PCA(n_components = 15)
X_train_pca = pca.fit_transform(X_train)  #fit_transform in case of training data
X_test_pca = pca.transform(X_test)  #transform in case of test data

# %%
lr = linear_model.LogisticRegression()

# %% [markdown]
# # Applying Logistic Regression on data without applying PCA

# %%
start = time.time()
lr.fit(X_train, y_train)
end = time.time()
print('Time' , end-start)
print('Score', lr.score(X_test, y_test))
# Out:
# Time 0.029983043670654297
# Score 0.9574468085106383
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
start1 = time.time()
lr.fit(X_train_pca, y_train)
end1 = time.time()
print('Time' , end1-start1)
print('Score', lr.score(X_test_pca, y_test))
# Out:
# Time 0.009991168975830078
# Score 0.9680851063829787
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %% [markdown]
# ### So the time of fitting the model after applying PCA on data is very less as compared to without PCA

# %% [markdown]
# # Eigen Vectors and Eigen values

# %%
pca.explained_variance_  #these are the eigen values
# Out:
# array([4.64358352e+05, 7.83940833e+03, 9.09369363e+02, 5.89143297e+01,
#        3.72408842e+01, 2.79720614e+00, 1.78562684e+00, 3.87244346e-01,
#        1.73561351e-01, 7.23506369e-02, 2.95910246e-02, 6.52862853e-03,
#        3.21936552e-03, 2.05979930e-03, 1.34598698e-03])

# %%
pca.components_  #these are the eigen vectors
# Out:
# array([[ 5.06050279e-03,  1.98898203e-03,  3.47932830e-02,
#          5.23458410e-01,  3.66198874e-06,  3.55975454e-05,
#          7.73961028e-05,  4.57239855e-05,  7.19775632e-06,
#         -3.12872164e-06,  3.21013140e-04, -4.40966563e-05,
#          2.25429730e-03,  5.81698884e-02, -7.30100339e-07,
#          4.24602930e-06,  7.96382032e-06,  2.93191472e-06,
#         -8.02652800e-07, -2.05830046e-07,  7.02946973e-03,
#          2.82751163e-03,  4.82333866e-02,  8.47925893e-01,
#          5.68931058e-06,  8.47305434e-05,  1.55719477e-04,
#          6.93292171e-05,  1.82828216e-05,  1.06335963e-07],
#        [ 8.84812140e-03, -3.41677824e-03,  5.96105313e-02,
#          8.46985237e-01, -1.65378680e-05, -1.11174511e-05,
#          6.80497952e-05,  3.80756245e-05, -2.00137279e-05,
#         -1.57859846e-05,  5.37779093e-05,  4.26160257e-04,
#          1.62374105e-03,  3.01422381e-02,  2.52140745e-06,
#          1.11198687e-05,  3.14741462e-05,  7.56306966e-06,
#          1.57967585e-05,  2.36061160e-07, -1.28776188e-03,
#         -1.34694364e-02, -4.64290342e-03, -5.27120905e-01,
#         -8.05255434e-05, -2.80959384e-04, -2.08825209e-04,
#         -5.24640736e-05, -1.46918007e-04, -5.50199625e-05],
#        [-1.21005532e-02, -1.89475812e-03, -7.06616365e-02,
#         -4.94237637e-02,  6.32869546e-05,  8.63521488e-05,
#          2.21385453e-04,  9.00279126e-06,  9.22880547e-05,
#          4.62384925e-05,  5.77068539e-03,  5.24576840e-03,
#          4.24640432e-02,  9.90588889e-01,  3.75635761e-05,
#          1.10263007e-04,  1.83986775e-04,  3.91505701e-05,
#          8.75914947e-05,  2.07288793e-05, -1.48548584e-02,
#         -2.34886576e-02, -8.74378162e-02, -2.94088576e-02,
#         -3.47892187e-05, -5.88019402e-04, -6.99707960e-04,
#         -3.08220028e-04, -3.92646349e-04, -2.59533304e-05],
#        [-3.68801715e-02, -3.40805727e-01, -3.43000053e-01,
#          3.92935602e-02, -3.49623373e-04, -2.93229145e-03,
#         -3.28701253e-03, -1.28077945e-03, -1.01219825e-03,
#         -1.69858280e-04, -4.62947177e-03, -2.09638274e-02,
#         -5.52186825e-02, -9.47138851e-02,  1.88527643e-05,
#         -8.85391806e-04, -1.02239864e-03, -2.61794598e-04,
#         -1.24048384e-04, -5.53884287e-05, -6.67071286e-02,
#         -5.04056026e-01, -7.00334571e-01,  3.95571033e-02,
#         -6.53925895e-04, -9.93205464e-03, -1.10088832e-02,
#         -3.15841244e-03, -2.63725946e-03, -7.90189864e-04],
#        [-3.41806079e-02,  4.63418783e-01, -2.96375709e-01,
#          4.24414031e-02, -4.63052322e-04, -2.16873308e-03,
#         -1.83060605e-03, -9.55802925e-04, -7.40200172e-04,
#         -1.66285157e-04, -3.25581113e-03,  3.73653802e-02,
#         -3.58570949e-02, -4.85075801e-02,  6.69124923e-05,
#         -3.76085854e-04, -4.61332102e-04, -1.90324638e-04,
#         -5.84432436e-05, -3.82664162e-05, -5.24786070e-02,
#          6.41866828e-01, -5.23730412e-01,  1.65923256e-02,
#         -3.15693572e-04, -4.97327134e-03, -5.58791695e-03,
#         -2.02707784e-03, -1.72056345e-03, -4.81716215e-04],
#        [-1.31278794e-01, -2.97929846e-01, -8.15120964e-01,
#          5.09185517e-02, -1.24611472e-04, -3.57405512e-04,
#          4.08019337e-04, -3.49761509e-04, -6.98999772e-05,
#          3.43794422e-04, -2.73389020e-03, -6.84738471e-03,
#          7.56427075e-02, -2.05192978e-02, -4.94586406e-05,
#         -1.74205910e-04, -4.76816586e-04, -5.18892494e-04,
#          4.65699700e-06, -3.27265748e-05, -6.91517778e-02,
#          1.76547726e-01,  4.28958801e-01, -1.97178283e-02,
#          2.19684069e-03,  1.39909747e-02,  1.34189478e-02,
#          2.57465272e-03,  7.32184797e-03,  2.02490323e-03],
#        [-4.98292092e-02,  7.50953567e-01, -2.76713501e-01,
#          1.34645326e-02, -1.53806317e-03, -1.73107607e-04,
#         -9.71323083e-04, -8.58640573e-04, -1.02770501e-03,
#          1.01690896e-04,  1.67149563e-02, -7.41819127e-02,
#          1.82615330e-01, -2.56407045e-02,  3.21634478e-04,
#          1.61066190e-03,  1.90510787e-03,  7.46623481e-04,
#          6.65238582e-04,  2.18056112e-04, -5.69150801e-02,
#         -5.37458269e-01,  1.57013137e-01, -3.82252418e-03,
#         -3.61907466e-03, -7.31233012e-03, -1.11922465e-02,
#         -4.18817545e-03, -7.37924049e-03, -1.08815158e-03],
#        [-7.03275099e-02, -8.78173052e-02,  8.70173405e-02,
#         -2.97883491e-03,  2.58643157e-03,  1.59956198e-02,
#          1.95481100e-02,  8.23275420e-03,  8.83602256e-03,
#          3.04316064e-03,  9.04478472e-02,  5.36067690e-01,
#          8.12408090e-01, -4.13922785e-02,  1.48762170e-03,
#          9.33943960e-03,  1.43451951e-02,  4.44983131e-03,
#          4.92425059e-03,  1.63045091e-03, -1.13835411e-01,
#          3.33124318e-02, -8.44335539e-02,  5.20013670e-03,
#         -3.01545898e-03, -5.54914058e-03,  1.96215584e-03,
#          1.06993290e-03, -8.96218362e-03,  6.74359357e-04],
#        [-3.52153983e-01,  4.16367048e-03,  1.38217727e-01,
#         -4.34581958e-03,  8.72556486e-03,  5.65354362e-02,
#          6.95769617e-02,  1.95704141e-02,  1.55523628e-02,
#          7.63527975e-03, -8.82331406e-02,  3.44021722e-02,
#         -1.77481649e-01,  4.17230051e-03,  1.40243909e-03,
#          1.95084372e-02,  2.52234829e-02,  3.52400121e-03,
#          6.81564918e-04,  2.22187991e-03, -8.64845409e-01,
#         -3.72293656e-03,  4.09613694e-02,  4.11473267e-03,
#          1.31544348e-02,  1.51069206e-01,  1.79806534e-01,
#          3.21718006e-02,  1.44139933e-02,  1.71473657e-02],
#        [ 1.21833233e-01,  8.64766474e-02, -9.00493871e-02,
#          2.23319931e-03, -1.92837368e-03, -2.65904959e-02,
#         -2.25754070e-02, -8.81338693e-03,  2.07285981e-03,
#         -3.63687491e-03, -1.44484427e-02,  8.27782786e-01,
#         -4.95573455e-01,  1.74013801e-02,  1.81512133e-03,
#         -3.51338247e-03, -1.72845197e-03, -1.34464907e-03,
#          3.91692972e-03,  1.11392916e-04,  3.63166149e-02,
#         -1.04019863e-01,  8.21876852e-02, -3.03791453e-03,
#         -1.01823163e-02, -8.64998963e-02, -9.53614884e-02,
#         -3.07093539e-02, -1.57795456e-02, -1.04571390e-02],
#        [-4.45185023e-01,  3.27058994e-02,  1.08820005e-02,
#          3.26610761e-03,  3.43155865e-02,  1.29036884e-01,
#          2.00099753e-01,  6.43482589e-02,  5.92205513e-02,
#          2.15842587e-02,  1.05976390e-01,  1.22893851e-01,
#         -8.01076015e-02,  1.21291808e-03,  5.13367501e-03,
#          4.20825822e-02,  7.90081186e-02,  9.19040764e-03,
#          1.17508131e-02,  6.94841312e-03,  4.18415345e-01,
#         -3.31924144e-02, -2.94260282e-02, -1.65632125e-03,
#          6.22006162e-02,  3.84903771e-01,  5.72100800e-01,
#          1.21058438e-01,  1.38664483e-01,  5.76453233e-02],
#        [ 7.38143296e-01,  1.01184770e-03, -8.58785448e-02,
#         -1.28129633e-03, -4.87065011e-02, -8.05453974e-02,
#          3.43499562e-02, -5.46494992e-02, -3.58911305e-02,
#         -1.14575951e-02, -5.27632934e-02,  4.42604242e-03,
#          5.22336212e-02, -7.34078040e-04, -4.76357162e-03,
#          4.38904639e-02,  1.28528393e-01,  1.37950199e-02,
#          1.85773987e-03,  4.95597311e-03, -1.64192233e-01,
#         -2.22364703e-03,  4.28218647e-03,  8.38683873e-04,
#         -5.67107621e-02,  1.95665505e-01,  5.83144879e-01,
#          1.72711261e-02, -1.21466592e-02,  1.06551829e-02],
#        [ 1.59309617e-01,  5.09452231e-03, -1.58618345e-02,
#         -2.66945091e-04,  1.27492468e-02,  9.49741236e-02,
#         -2.20437653e-01, -2.98873337e-02,  1.60461897e-01,
#          9.89192642e-03, -9.01969406e-02,  2.09390364e-02,
#          2.32737355e-02, -2.25646254e-04, -2.18911907e-03,
#          3.90515872e-02, -1.35896849e-01, -1.01081064e-02,
#          5.81896984e-02, -1.98219581e-03, -2.69190221e-02,
#         -5.02067718e-03, -3.80662325e-03,  3.04273136e-04,
#          1.72647368e-02,  6.37255218e-01, -3.62646858e-01,
#          2.65474861e-02,  5.61425982e-01,  5.14722583e-02],
#        [ 5.36292036e-02, -1.04200365e-03, -9.94066362e-04,
#         -3.56413154e-04,  2.90453775e-02, -4.16627775e-02,
#          1.87938315e-01,  7.70025261e-02,  2.91418706e-01,
#         -1.90209049e-03,  2.34308416e-01, -3.13576968e-02,
#         -1.57560971e-02, -5.69299837e-04, -8.17397057e-04,
#         -5.31049546e-02,  6.92986243e-02,  6.55575839e-03,
#          6.87813614e-02, -2.39554990e-03, -7.51548403e-02,
#          3.16226461e-03,  4.97505689e-03,  2.49900591e-04,
#          1.93442927e-02, -5.21602909e-01,  1.23375574e-01,
#          6.09463944e-02,  7.07597595e-01, -4.55124290e-02],
#        [-1.22944834e-01,  7.32865630e-03,  1.21261094e-02,
#          1.47909373e-04, -5.44062710e-02, -9.41135519e-02,
#         -7.80657917e-02, -5.71642064e-02, -1.07596330e-02,
#         -1.14323663e-02, -9.13834839e-01,  4.20348635e-02,
#          8.41425927e-02,  1.63906126e-03, -1.49898661e-02,
#         -3.86103438e-02, -5.01046289e-02, -7.94938767e-03,
#          1.50234120e-02, -8.21677929e-03,  1.12630935e-01,
#         -7.60075939e-03, -9.64826166e-03, -2.17155549e-04,
#         -6.65300389e-02, -1.93734452e-01,  1.56276813e-01,
#         -6.59081825e-03,  1.88112336e-01, -9.15492136e-03]])
